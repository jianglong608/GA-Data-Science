# %% [markdown]
# <div class="clearfix" style="padding: 10px; padding-left: 0px">
# <img src="https://raw.githubusercontent.com/jupyter/nature-demo/master/images/jupyter-logo.png" width="150px" style="display: inline-block; margin-top: 5px;">
# <a href="http://bit.ly/tmpnbdevrax"><img src="https://cloud.githubusercontent.com/assets/836375/4916141/2732892e-64d6-11e4-980f-11afcf03ca31.png" width="150px" class="pull-right" style="display: inline-block; margin: 0px;"></a>
# </div>
#
# ## Welcome to the Temporary Notebook (tmpnb) service!
#
# This Notebook Server was **launched just for you**. It's a temporary way for you to try out a recent development version of the IPython/Jupyter notebook.
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# <p>**WARNING**</p>
#
# <p>Don't rely on this server for anything you want to last - your server will be *deleted after 10 minutes of inactivity*.</p>
# </div>
#
# Your server is hosted thanks to [Rackspace](http://bit.ly/tmpnbdevrax), on their on-demand bare metal servers, [OnMetal](http://bit.ly/onmetal).

# %% [markdown]
# ### Run some Python code!
#
# To run the code below:
#
# 1. Click on the cell to select it.
# 2. Press `SHIFT+ENTER` on your keyboard or press the play button (<button class='fa fa-play icon-play btn btn-xs btn-default'></button>) in the toolbar above.
#
# A full tutorial for using the notebook interface is available [here](ipython_examples/Notebook/Index.ipynb).

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
import seaborn as sns

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# # this is a test

# %% [markdown]
# ## how about this
# ### and sometimes you got to use 3 hashes

# %% [markdown]
# ###### when you use six hashes this is how it looks like

# %% [markdown]
# ### try use some italic words here
# *today's topic is about how to use markdown* /n
# _is this gonna be italic too?_
#
# ** how about this line **
# __is this gonna be bold too?__
#
# _and you **can** combine them_
#
# * item 1
# * item 2
# * item 3
#  * subitem
#      * another item
#
#
# 1. what about this
# 2. second step even better
# 3. last but not the least
#     * some item here
#
# _but this is not_
#
# ### try some images here
# !![GitHub Logo](/images/logo.png)
# Format: ![Alt Text](url)
#
# #link bad example
# # links
#
# http://github.com - automatic!
# [GitHub](http://github.com)
#
# # Blockquotes
# As Kanye West said:
#
# > We're living the future so
# > the present is our past
#
# # inline code
#
# *I think you should use an*
# `<addr>` element here instead.
#
# ```javascript
# function fancyAlert(arg) {
#   if(arg) {
#     $.facebox({div:'#foo'})
#   }
# }
# ```
# _asd_
#
#     function fancyAlert(arg) {
#       if(arg) {
#         $.facebox({div:'#foo'})
#       }
#     }

# %% [markdown]
# ### excercise 4, class
# *simply indent the code four spaces*
#
#     class store():
#         def __init__(self, inventory):
#             self.inventory = inventory
#
#         def show_inventory(self):
#             print(self.inventory)
#
#         def message_customer(self, customer):
#             for item in customer.fruit:
#                 if item in inventory:
#                     print("The store has {} and its cost is ${}".format(item, self.inventory[item]) )
#             else:
#                 print("The store does not have anything you want")
#                 print(customer.greeting)

# %%
class store():
    def __init__(self, inventory):
        self.inventory = inventory

    def show_inventory(self):
        print(self.inventory)

    def message_customer(self, customer):
        for item in customer.fruit:
            if item in inventory:
                print("The store has {} and its cost is ${}".format(item, self.inventory[item]) )
        else:
            print("The store does not have anything you want")
            print(customer.greeting)

# %% [markdown]
# ### make a table here
#
# First Header | Second Header
# ------------ | -------------
# Content from cell 1 | Content from cell 2
# Content in the first column | Content in the second column

# %% [markdown]
# @jianglong608

# %% [markdown]
# when you had a chance could you please turn on the light?
# here are the steps:
#
# 1. go the to room
# 2. go find the switch
# 3. turn on the light
#
# Or just do this:
#
# * find a good spot
# * don't do anything

# %% [markdown]
#     def foo():
#         if not bar:
#             return True

# %% [markdown]
# ~~this~~

# %% [markdown]
# ### task list
# - go find out who's the manager
# - tell them their customer serivce suck
# - see if that can resolve the issue themselves
# - or just quit

# %% [markdown]
# Feel free to open new cells using the plus button (<button class='fa fa-plus icon-plus btn btn-xs btn-default'></button>), or hitting shift-enter while this cell is selected.
#
# Behind the scenes, the software that powers this is [tmpnb](https://github.com/jupyter/tmpnb), a  Tornado application that spawns [pre-built Docker containers](https://github.com/ipython/docker-notebook) and then uses the [jupyter/configurable-http-proxy](https://github.com/jupyter/configurable-http-proxy) to put your notebook server on a unique path.

# %%
print(__name__)
# Out:
# __main__

# %%
# excercise 4, class

class store():
    def __init__(self, inventory):
        self.inventory = inventory
    
    def show_inventory(self):
        return self.inventory
        
    def message_customer(self, customer):
        count = 0
        for item in customer.preferred_fruit:
            if item in self.inventory:
                print("{}, The store has {} and its cost is ${}".format(customer.formal_greeting(), item, 
                                                                        self.inventory[item]) )
                count += 1
       
        if count == 0:
            print(customer.formal_greeting())            
            print("The store does not have anything you want")
            

                



class customer():
    def __init__(self, first_name, last_name, is_male, money, preferred_fruit, fruit = {}):
        self.first_name = first_name
        self.last_name = last_name
        self.is_male = is_male
        self.money = money
        self.fruit = fruit
        self.preferred_fruit = preferred_fruit
    
    def formal_greeting(self):
        if self.is_male == True:
            return('Mr. {} {}'.format(self.first_name, self.last_name))
        else:
            return('Ms. {} {}'.format(self.first_name, self.last_name))
    
    def buy_fruit(self, store, fruit_name, fruit_amt):
        if fruit_name not in store.inventory:
            print('The store does not have {}'.format(fruit_name))
        elif self.money < store.inventory[fruit_name] * fruit_amt:
            print("Sorry, you don't have enough money")
        else:
            self.money -= store.inventory[fruit_name] * fruit_amt
            if fruit_name in self.fruit:
                self.fruit[fruit_name] += fruit_amt
            else:
                self.fruit[fruit_name] = fruit_amt

# %% [markdown]
# - Mindy Smith - \$5.25, likes apples and oranges
# - Al Johri - \$20.19, likes papaya, strawberries, pinapple, and apples
# - Hillary Clinton - \$15, likes strawberries and oranges
# - Oliver Twist - \$.05, likes apples
# - Donald Trump - \$4000, only likes durian

# %%
mindy = customer(first_name = "Mindy", last_name = "Smith", is_male = False, 
                 money = 5.25, preferred_fruit = ["apple", "orange"])

al = customer(first_name = 'Al', last_name = 'Johri', is_male = True, 
              money = 20.19, preferred_fruit = ["papaya", "strawberries", 'pinapple', 'apple'])

hillary = customer(first_name = 'Hillary', last_name = 'Clinton', is_male = False, 
              money = 15, preferred_fruit = ["strawberries", "orange"])

oliver = customer(first_name = 'Oliver', last_name = 'Twist', is_male = False, 
              money = .05, preferred_fruit = ["apple"])

donald = customer(first_name = 'Donald', last_name = 'Trump', is_male = True, 
              money = 4000, preferred_fruit = ["durian"])

# %% [markdown]
# Create a store called Whole Foods with the following inventory
#
# * 'apple' : \$.29
# * 'banana': \$.05
# * 'orange': \$.20
# * 'strawberries': \$.30
# * 'pinapple': \$1.50,
# * 'grapes': \$.22,
# * 'durian': \$5000

# %%
WFinven = {
    'apple' : .29,
    'banana': .05,
    'orange': .20,
    'strawberries': .30,
    'pinapple': 1.50,
    'grapes': .22,
    'durian': 5000
}

WholeFoods = store(inventory = WFinven)

# %%
WholeFoods.message_customer(hillary)
# Out:
# Ms. Hillary Clinton, The store has strawberries and its cost is $0.3
# Ms. Hillary Clinton, The store has orange and its cost is $0.2

# %%
donald.formal_greeting()
hillary.formal_greeting()
# Out:
# 'Ms. Hillary Clinton'

# %%
print(hillary.money, hillary.fruit)
print(al.money, al.fruit)
print(oliver.money, oliver.fruit)
print(mindy.money, mindy.fruit)
print(donald.money, donald.fruit)
# Out:
# 15 {}
# 20.19 {}
# 0.05 {}
# 5.25 {}
# 4000 {}

# %%
for item in hillary.preferred_fruit:
    hillary.buy_fruit(WholeFoods, item, 1)
                      
print(hillary.money, hillary.fruit)
print(al.money, al.fruit)
print(oliver.money, oliver.fruit)
print(mindy.money, mindy.fruit)
print(donald.money, donald.fruit)
# Out:
# 14.5 {'orange': 1, 'strawberries': 1}
# 20.19 {'orange': 1, 'strawberries': 1}
# 0.05 {'orange': 1, 'strawberries': 1}
# 5.25 {'orange': 1, 'strawberries': 1}
# 4000 {'orange': 1, 'strawberries': 1}

# %%
for fruit in al.preferred_fruit:
    al.buy_fruit(WholeFoods, fruit, 1)

al.money, al.fruit
# Out:
# The store does not have papaya
# (18.1, {'apple': 1, 'orange': 1, 'pinapple': 1, 'strawberries': 2})

# %%
for fruit in oliver.preferred_fruit:
    oliver.buy_fruit(WholeFoods, fruit, 1)
    
oliver.money, oliver.fruit
# Out:
# Sorry, you don't have enough money
# (0.05, {'apple': 1, 'orange': 1, 'pinapple': 1, 'strawberries': 2})

# %%
for fruit in mindy.preferred_fruit:
    mindy.buy_fruit(WholeFoods, fruit, 1)
    
mindy.money, mindy.fruit
# Out:
# (4.76, {'apple': 2, 'orange': 2, 'pinapple': 1, 'strawberries': 2})

# %%
for fruit in donald.preferred_fruit:
    donald.buy_fruit(WholeFoods, fruit, 1)
    
donald.money, donald.fruit
# Out:
# Sorry, you don't have enough money
# (4000, {'apple': 2, 'orange': 2, 'pinapple': 1, 'strawberries': 2})
